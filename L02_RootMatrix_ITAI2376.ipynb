# %% [markdown]
# L02 Exploring Deep Learning Tools: A No-Code Introduction to TensorFlow and Keras
#
# Introduction
#
# We read the introduction and understood that the main goal of this lab is to learn how deep learning and pre-trained models work using a no-code approach with Google Colab and VGG16.

# %%
import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np

model = VGG16(weights='imagenet')
model.summary()
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 9s 0us/step
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
from tensorflow.keras.utils import load_img, img_to_array

def prepare_image(img_path):
    img = load_img(img_path, target_size=(224, 224))
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return x

# %%
# !wget -O elephant.jpg https://upload.wikimedia.org/wikipedia/commons/f/fc/African_Bush_Elephant.jpg

img_path = 'elephant.jpg'
image_data = prepare_image(img_path)
preds = model.predict(image_data)

results = decode_predictions(preds, top=3)[0]
for i, (imagenet_id, label, score) in enumerate(results):
    print(f"{i+1}. {label}: {score*100:.2f}%")
# Out:
# --2026-09-05 15:58:02--  https://upload.wikimedia.org/wikipedia/commons/f/fc/African_Bush_Elephant.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.240, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.240|:443... connected.
# HTTP request sent, awaiting response... 429 Too Many Requests (015d12c)
# 2026-09-05 15:58:02 ERROR 429: Too Many Requests (015d12c).
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# /tmp/ipykernel_1027/1651415245.py in <cell line: 0>()
#       2
#       3 img_path = 'elephant.jpg'
# ----> 4 image_data = prepare_image(img_path)
#       5 preds = model.predict(image_data)
#       6
#
# /tmp/ipykernel_1027/3265449507.py in prepare_image(img_path)
#       2
#       3 def prepare_image(img_path):
# ----> 4     img = load_img(img_path, target_size=(224, 224))
# ...

# %%
from google.colab import files
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
    img_path = fn
    image_data = prepare_image(img_path)
    preds = model.predict(image_data)

    results = decode_predictions(preds, top=3)[0]
    print(f"\n--- Results for {fn} ---")
    for i, (imagenet_id, label, score) in enumerate(results):
        print(f"{i+1}. {label}: {score*100:.2f}%")
# Out:
#      <input type="file" id="files-983d2e92-9581-4f91-9b94-16b0ff4f2d7b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-983d2e92-9581-4f91-9b94-16b0ff4f2d7b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import random_shift, random_rotation

img_to_test = load_img(fn, target_size=(224, 224))
x_orig = img_to_array(img_to_test)

x_modified = random_shift(x_orig, wrange=0.2, hrange=0.2, row_axis=0, col_axis=1, channel_axis=2)
x_input = np.expand_dims(x_modified, axis=0)
x_input = preprocess_input(x_input)

preds_mod = model.predict(x_input)
results_mod = decode_predictions(preds_mod, top=3)[0]

print(f"\n--- Results after modifying image (Step 5) ---")
for i, (imagenet_id, label, score) in enumerate(results_mod):
    print(f"{i+1}. {label}: {score*100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1027/3435012102.py in <cell line: 0>()
#       6 x_orig = img_to_array(img_to_test)
#       7
# ----> 8 x_modified = random_shift(x_orig, wrange=0.2, hrange=0.2, row_axis=0, col_axis=1, channel_axis=2)
#       9 x_input = np.expand_dims(x_modified, axis=0)
#      10 x_input = preprocess_input(x_input)
#
# TypeError: random_shift() got an unexpected keyword argument 'wrange'

# %%
import numpy as np

x_modified = np.roll(x_orig, shift=15, axis=1)
x_input = np.expand_dims(x_modified, axis=0)
x_input = preprocess_input(x_input)

preds_mod = model.predict(x_input)
results_mod = decode_predictions(preds_mod, top=3)[0]

print(f"\n--- Results after modifying image (Step 5) ---")
for i, (imagenet_id, label, score) in enumerate(results_mod):
    print(f"{i+1}. {label}: {score*100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 904ms/step
#
# --- Results after modifying image (Step 5) ---
# 1. racer: 61.37%
# 2. sports_car: 37.66%
# 3. cab: 0.43%

# %% [markdown]
# Conclusion and Discussion
#
# We completed a 6-step deep learning lab in Google Colab using the pre-trained VGG16 model and ImageNet weights. This allowed us to test computer vision and image classification without writing code from scratch.
#
#
# Step-by-Step Lab Process and Error Details:
#
# Steps 1 and 2 (Model Setup): We imported TensorFlow and VGG16. Running model.summary() showed that the model has 138,357,544 parameters and takes 527.79 MB of memory, confirming it has the structure needed to extract image shapes and features.
#
# Steps 3 and 4 (Data Upload and Prediction Error):
#
# First Error: When we tried to download a default image (elephant.jpg) using wget, the server gave an HTTP 429 Too Many Requests error and failed.
#
# The Fix: We used the interactive tool files.upload() to upload our own image of a car (Classic Car.webp) directly from our computer.
#
# Prediction Result: The model successfully identified the car as racer (60.62%) and sports_car (38.92%), showing it works well for vehicle classes.
#
# Step 5 (Pixel Shift and Testing Sensitivity):
#
# Code Error: Trying to use Keras's random_shift function caused a TypeError because an argument (wrange) was not supported in this version.
#
# The Fix: We replaced it with NumPy's shift function (np.roll(..., shift=15, axis=1)) to move the image pixels 15 pixels to the right.
#
# Result Change: Moving the pixels slightly changed the prediction scores. The top prediction (racer) went up from 60.62% to 61.37%, and cab appeared in third place instead of car_wheel. This proves that deep learning models are sensitive to small changes in position and pixel alignment.
#
# Final Reflection
#
# This lab showed that pre-trained models like VGG16 can classify images instantly using transfer learning. However, it also proved that model outputs can shift when the input image pixels are moved or altered.

# %% [markdown]
# Feedback and Assessment
#
# As a group, we think this lab was very practical and helpful to understand how pre-trained deep learning models work without writing complex code from scratch.
#
# During the practice, we learned how to import the default model architecture called VGG16 using TensorFlow, how to handle image data preprocessing, and how to make successful predictions using our own classic car photo.
#
# We also saw that AI models are very sensitive to spatial changes. When we modified and shifted the image pixels slightly, the confidence percentages and alternative labels changed, which clearly shows how visual alignment affects model behavior.
